# %%
import cv2
import torch

mask = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='mask.pt', force_reload=True) 
fire = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='fire.pt', force_reload=True) 
weapon = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='weapon_best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\abo khaled/.cache\torch\hub\master.zip
# YOLOv5  2023-2-12 Python-3.9.13 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients
# Adding AutoShape...
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\abo khaled/.cache\torch\hub\master.zip
# YOLOv5  2023-2-12 Python-3.9.13 torch-1.13.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\abo khaled/.cache\torch\hub\master.zip
# YOLOv5  2023-2-12 Python-3.9.13 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# import cv2
# import torch
# fire = torch.hub.load('ultralytics/yolov5', 'custom',
#  path='fire.pt', force_reload=True)

# %% [markdown]
# import cv2
# import torch
# weapon = torch.hub.load('ultralytics/yolov5', 'custom',
#  path='weapon_best.pt', force_reload=True)

# %%
list_res=[0,0,0]
list_mask=[0,0,0]
list_wep=[0,0,0]
final=[]

# %%
cap=cv2.VideoCapture('document_6003505440967626004 (1).mp4')
cap.set(3, 640)
cap.set(4, 640)
##########################################
size = (640, 640)
result_video = cv2.VideoWriter('filename.mp4', 
                         cv2.VideoWriter_fourcc(*'MJPG'),
                         10, size)
##########################################

while cap.isOpened() :
    ret, frame = cap.read()
    if not ret:
        break
    
    
    
    results = fire(frame, size=640)  
    res=results.pandas().xyxy[0]
    for i in range (len(res)) :
        xmin,ymin,xmax,ymax,confidence,_,_=res.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.1 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(res.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            list_res.append(1)
        else:
            list_res.append(0)
        
    res_w = weapon(frame, size=640)  
    re_w=res_w.pandas().xyxy[0]
    for i in range (len(re_w)) :
        xmin,ymin,xmax,ymax,confidence,_,_=re_w.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.3 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(re_w.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            list_wep.append(1)
        else:
            list_wep.append(0)
    res_m = mask(frame, size=640)  
    re_m=res_m.pandas().xyxy[0]
    for i in range (len(re_m)) :
        xmin,ymin,xmax,ymax,confidence,_,_=re_m.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.3 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(re_m.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            list_mask.append(1)
        else:
            list_mask.append(0)
    
    f=len(list_res)
    if list_res[f-1]==1 and list_res[f-2]==1:
        final.append('fire')
    m=len(list_mask)
    if list_mask[m-1]==1 and list_mask[m-2]==1:
        final.append('mask')
    w=len(list_wep)
    if list_wep[w-1]==1 and list_wep[w-2]==1:
        final.append('weapon')
    print(final)
    
    final.clear()

    result_video.write(frame)
    cv2.imshow("Project", frame)
    
    # Exit if ESC pressed
    if cv2.waitKey(1) & 0xFF == ord('q'): # if press SPACE bar
        break
cap.release()
result_video.release()
cv2.destroyAllWindows()
# Out:
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask', 'weapon']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ['fire', 'mask']
# ...

# %%
cap=cv2.VideoCapture('YouCut_20221130_154235017.mp4')
cap.set(3, 640)
cap.set(4, 640)
##########################################
size = (640, 640)
result_video = cv2.VideoWriter('filename.avi', 
                         cv2.VideoWriter_fourcc(*'MJPG'),
                         10, size)
##########################################

while cap.isOpened() :
    ret, frame = cap.read()
    if not ret:
        break
    
    
    
    results = mask(frame, size=640)  
    res=results.pandas().xyxy[0]
    for i in range (len(res)) :
        xmin,ymin,xmax,ymax,confidence,_,_=res.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.1 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(res.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            list_res.append(1)
            
        else:
            list_res.append(0)
    
    
    s=len(list_mask)
    if list_mask[s-1]==1 and list_mask[s-2]==1:
        print('mask')

    result_video.write(frame)
    cv2.imshow("Project", frame)
    
    # Exit if ESC pressed
    if cv2.waitKey(1) & 0xFF == ord('q'): # if press SPACE bar
        break
cap.release()
result_video.release()
cv2.destroyAllWindows()

# %%
cap=cv2.VideoCapture('project1.mp4')
cap.set(3, 640)
cap.set(4, 640)
##########################################
size = (640, 640)
result_video = cv2.VideoWriter('filename.avi', 
                         cv2.VideoWriter_fourcc(*'MJPG'),
                         10, size)
##########################################

while cap.isOpened() :
    ret, frame = cap.read()
    if not ret:
        break
    
    
    
    results = weapon(frame, size=640)  
    res=results.pandas().xyxy[0]
    for i in range (len(res)) :
        xmin,ymin,xmax,ymax,confidence,_,_=res.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.1 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(res.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            list_res.append(1)
        else:
            list_res.append(0)
    
    
    s=len(list_wep)
    if list_wep[s-1]==1 and list_wep[s-2]==1:
        print('weapon')
       
        
    result_video.write(frame)
    cv2.imshow("Project", frame)
    
    # Exit if ESC pressed
    if cv2.waitKey(1) & 0xFF == ord('q'): # if press SPACE bar
        break
cap.release()
result_video.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture('http://192.168.1.6:8080/video')

import cv2
import numpy as np
import requests
import io

ip = input("Enter the ipv4 address for your ip webcam: ")
url = ip + "/shot.jpg"
while True:

    img_request = requests.get(url)
    img_arrint = np.array(bytearray(img_request.content), dtype=np.uint8)
    img = cv2.imdecode(img_arrint, -1)
    
    results = model(frame, size=640)  
    res=results.pandas().xyxy[0]
    for i in range (len(res)) :
        xmin,ymin,xmax,ymax,confidence,_,_=res.iloc[i,:]
        xmin,ymin,xmax,ymax=int(xmin),int(ymin),int(xmax),int(ymax)
        if confidence > 0.6 :
            cv2.rectangle(frame, (xmin , ymin), (xmax , ymax), (255, 0, 0), 2)
            cv2.putText(frame, str(res.name[i]), (xmin , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.putText(frame, str(round(confidence,2)), (xmin+50 , ymin), cv2.FONT_HERSHEY_SIMPLEX,1, (255, 0, 0), 2, cv2.LINE_AA) 
    
    
    cv2.imshow("video-stream", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

# %%
import cv2
import datetime
cap = cv2.VideoCapture('http://192.168.1.6:8080/video')
#cap = cv2.VideoCapture('rtsp://192.168.1.6:8080/1')

fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('out.avi',fourcc,20.0,(640,480))
while(True):
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    #frame=cv2.flip(frame,0)
    
    results = model(frame)
    #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    out.write(frame) 
    #print(results)
    cv2.imshow('frame',frame)
    ss=str(results)
    print(ss[18:27])
    if cv2.waitKey(1)==ord('q'):
        break
        
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('data/haarcascades/haarcascade_eye.xml')

video_capture = cv2.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    res=
        
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture('http://192.168.1.7:8080/video')

import cv2
import numpy as np
import requests
import io

ip = input("Enter the ipv4 address for your ip webcam: ")
url = ip + "/shot.jpg"
cap.set(3,100)
cap.set(4,100)
while True:

    img_request = requests.get(url)
    img_arrint = np.array(bytearray(img_request.content), dtype=np.uint8)
    img = cv2.imdecode(img_arrint, -1)
    
    results = model1(img)
    ss=str(results)
    print(ss[18:35])
    
    
    cv2.imshow("video-stream", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

# %%
import cv2
import torch

model1 = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='best _weapon.pt', force_reload=True)

# %%
video_capture = cv2.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    
    
    results = model(frame)
    ss=str(results)
    print(ss[18:35])
        
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()

# %%
n=[1,2,3,4,5,6]
n[5]
# Out:
# 6

# %%
len(n)
# Out:
# 6
